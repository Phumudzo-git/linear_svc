# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.svm import LinearSVC
from imblearn.over_sampling import ADASYN, SMOTE, RandomOverSampler
from sklearn.utils import shuffle
import pickle
import nltk
from nltk import word_tokenize
from nltk.tokenize import WordPunctTokenizer
from sklearn.utils import resample

# %%
data = './lang_data.csv'
df = pd.read_csv(data, encoding = 'ISO-8859-1')

# %%
print(df)
# Out:
#                                                    text    language
# 0                        Ship shape and Bristol fashion     English
# 1                                        Know the ropes     English
# 2                                       Graveyard shift     English
# 3                                Milk of human kindness     English
# 4                    Touch with a barge-pole - Wouldn't     English
# 5                    Sy kan altyd my battery natpiepie.   Afrikaans
# 6                            When the shit hits the fan     English
# 7                                                   NaN   Afrikaans
# 8                                                Egg on     English
# 9                                             Drag race     English
# 10                          As queer as a nine bob note     English
# 11                                                  NaN   Afrikaans
# 12                                     Run the gauntlet     English
# 13                                Raining cats and dogs     English
# 14                                   No laughing matter     English
# 15                                      Run of the mill     English
# 16    Piet Pompies van Soetmelksvlei is nie van hier...   Afrikaans
# 17                                                  NaN   Afrikaans
# 18                                  A drop in the ocean     English
# 19                                           In a trice     English
# 20                                       Auld lang syne     English
# 21                                        Dock your pay     English
# 22                                      Fair and square     English
# 23                            As snug as a bug in a rug     English
# 24                                    Christmas box - A     English
# 25                      Pip - Get the/got the /have the     English
# 26                     Life's not all beer and skittles     English
# 27                                  Twenty three skidoo     English
# 28    Die lewe is 10 % wat met ons gebeur en 90 % on...   Afrikaans
# 29                                           Fancy free     English
# ...                                                 ...         ...
# 2809                             Pull out all the stops     English
# 2810                                          Bottom-up     English
# 2811                                     Rise and shine     English
# 2812                   As different as chalk and cheese     English
# 2813                                                NaN   Afrikaans
# 2814                                            Pony up     English
# 2815                     Praying at the porcelain altar     English
# 2816                           Get thee behind me Satan     English
# 2817  Wat regtig saak maak, is wat jy leer terwyl jy...   Afrikaans
# 2818                                          Duvet day     English
# 2819                         Bury your head in the sand     English
# 2820                           Hit the nail on the head     English
# 2821  Vergelyk eers wat jy het met wat jy nie het ni...   Afrikaans
# 2822                             A feather in one's cap     English
# 2823                              Delusions of grandeur     English
# 2824                                 Devil to pay - The     English
# 2825       Wat is die belangrikste â geluk of sukses?   Afrikaans
# 2826                             Waar rook is, is vuur.  Nederlands
# 2827                    If it ain't broke, don't fix it     English
# 2828                                          For keeps     English
# 2829                   Golden key can open any door - A     English
# 2830                                         Knock back     English
# 2831                                        Tit for tat     English
# 2832  Die boer se voetspore is die beste misstof op ...   Afrikaans
# 2833                                     Swing the lead     English
# 2834                        Daarâs ân geurtjie aan.   Afrikaans
# 2835  Men's evil manners live in brass; their virtue...     English
# 2836                                          Go-faster     English
# 2837                                           Red tape     English
# 2838                                        In a pickle     English
#
# [2839 rows x 2 columns]

# %%
df=resample(df, random_state=0)
df
# Out:
#                                                    text    language
# 2732                                           A priori     English
# 2607                            Great minds think alike     English
# 1653      Zoals de waard is, vertrouwt hij zijn gasten.  Nederlands
# 835                                     Bag and baggage     English
# 763                                      Below the belt     English
# 1731                     The smallest room in the house     English
# 1033                                        Fools' gold     English
# 277                                     Crocodile tears     English
# 1778                                     Bald as a coot     English
# 1828                                       Bog standard     English
# 2647  Ring a ring o'roses, a pocketful of posies, at...     English
# 2648                                As brown as a berry     English
# 2362                                        Upper crust     English
# 705                             Lay it on with a trowel     English
# 2599                                         Giddy aunt     English
# 2135                                         Eighty six     English
# 2222  Dit is net die oortjies van die seekoei wat on...   Afrikaans
# 1701         Little of what you fancy does you good - A     English
# 537                                  Last but not least     English
# 2120  Jan van Rooy, vang ân vlooi â poef hom roo...   Afrikaans
# 2825       Wat is die belangrikste â geluk of sukses?   Afrikaans
# 1940                                          Iron hoof     English
# 2163                                     Pie in the sky     English
# 976                           Alte goed is buurmansgek.   Afrikaans
# 755       Julius se gesante en trawante raak al minder.   Afrikaans
# 2046                                     How do you do?     English
# 1871                                        In the buff     English
# 2496                                            Dust up     English
# 99                                    Put up your dukes     English
# 2008                                        Getik wees.   Afrikaans
# ...                                                 ...         ...
# 449                        Good man is hard to find - A     English
# 1341                                  Land of nod - The     English
# 488                            All singing, all dancing     English
# 999    ân Gedurige gedrup maak ân gat in ân klip.   Afrikaans
# 2471                                     Sick puppy (A)     English
# 105                                 Got my mojo working     English
# 2735               Sir Walter Scott (phrases coined by)     English
# 2157                     He will give the Devil his due     English
# 1952                                         Old codger     English
# 377                 It's better to give than to receive     English
# 260                                     Chinless wonder     English
# 1462  Die Julius is hardekoejawel, inkoejawel en ingat!   Afrikaans
# 2432                          Road less travelled - The     English
# 267                                    In die gras byt.   Afrikaans
# 179                                   Broad in the beam     English
# 611                                  The great unwashed     English
# 964   To sleep: perchance to dream: ay, there's the rub     English
# 2545                            High, wide and handsome     English
# 732   You can lead a horse to water but you can't ma...     English
# 912                          Uit het oog, uit het hart.  Nederlands
# 884             Hy is op die afdraand met sy briek los.   Afrikaans
# 1094                                         Make haste     English
# 2808             Fool and his money are soon parted - A     English
# 2143                                   Not a dicky-bird     English
# 1026                               Vanish into thin air     English
# 508                        Fall off the back of a lorry     English
# 2208                      Geld groei nie op my rug nie.   Afrikaans
# 2273                         De puntjes op de i zetten.  Nederlands
# 1446                        Chickens come home to roost     English
# 2628                              Christmas card verses     English
#
# [2839 rows x 2 columns]

# %%
df['language'].value_counts()
# Out:
# English       2007
# Afrikaans      710
# Nederlands     122
# Name: language, dtype: int64

# %%
df.isnull().sum(axis = 0)
# Out:
# text        94
# language     0
# dtype: int64

# %%
df['text'].isnull().sum()
# Out:
# 94

# %%
df['language'].isnull().sum()
# Out:
# 0

# %%
df.dropna(inplace=True)

# %%
df['text'].isnull().sum()
# Out:
# 0

# %%
df['language'].value_counts()
# Out:
# English       1984
# Afrikaans      679
# Nederlands      82
# Name: language, dtype: int64

# %% [markdown]
# ## Cleaning function

# %%
tok = WordPunctTokenizer()
def document_cleaner(text):
    words = [x for x in  tok.tokenize(text) if x.isalpha()]
    words = " ".join(words)
    return(words.lower())

# %%
lsvc = LinearSVC(C=0.1)
count_vect = CountVectorizer(ngram_range=(1,1))#, encoding='latin-1')

# %% [markdown]
# ## Main function to run the for training of the model

# %%
def main(df, p):
    df['text'] = df['text'].apply(document_cleaner)
    ros = RandomOverSampler(random_state=777)
    x_train, x_test, y_train, y_test = train_test_split(df['text'], df['language'], test_size=0.7, random_state=2000)
  
    x_train = count_vect.fit_transform(x_train)
    tfidf_vectorizer = TfidfVectorizer(use_idf=True, ngram_range=(1,2))
    vectorize = TfidfTransformer()
    x_train = vectorize.fit_transform(x_train)
    X_ROS, y_ROS = ros.fit_sample(x_train, y_train)
    
    #fit the model
    lsvc.fit(X_ROS, y_ROS)
    
    #prediction
    prediction_1 = lsvc.predict(count_vect.transform(df['text']))
    prediction_2 = lsvc.predict(count_vect.transform(x_test))
    
    #print("LinearSVC Model: 2gram")
    print("LinearSVC Model: Bigram- Scores for the whole dataset")
    print(classification_report(prediction_1, df['language']))
    print("LinearSVC Model: Bigram- Scores for the test dataset")
    print('Accuracy for the tese dataset:',accuracy_score(y_test, prediction_2))
    print('Classification report:''\n',classification_report(y_test, prediction_2))
    print('Confusion matrix for the test dataset: ''\n', confusion_matrix(y_test, prediction_2))

# %%
print(main(df, 35))
# Out:
# LinearSVC Model: Bigram- Scores for the whole dataset
#               precision    recall  f1-score   support
#
#    Afrikaans       0.98      0.94      0.96       702
#      English       0.98      0.99      0.99      1962
#   Nederlands       0.94      0.95      0.94        81
#
#     accuracy                           0.98      2745
#    macro avg       0.97      0.96      0.96      2745
# weighted avg       0.98      0.98      0.98      2745
#
# LinearSVC Model: Bigram- Scores for the test dataset
# Accuracy for the tese dataset: 0.9745057232049948
# Classification report:
#                precision    recall  f1-score   support
#
#    Afrikaans       0.94      0.97      0.96       477
#      English       0.99      0.98      0.98      1391
#   Nederlands       0.92      0.91      0.92        54
#
#     accuracy                           0.97      1922
#    macro avg       0.95      0.95      0.95      1922
# weighted avg       0.97      0.97      0.97      1922
#
# Confusion matrix for the test dataset:
#  [[ 462   14    1]
#  [  26 1362    3]
#  [   2    3   49]]
# None

# %%
pickle.dump(lsvc, open('model_1.pkl','wb'))
pickle.dump(count_vect, open('model_2.pkl', 'wb'))

# %%
lsvc = pickle.load(open('model_1.pkl','rb'))
count_vect = pickle.load(open('model_2.pkl', 'rb'))

# %%
df['text']
# Out:
# 444                     hy kedoem sy kitaar so nou en dan
# 851                                           grond vreet
# 751                                   a fish out of water
# 277                                       crocodile tears
# 988                                          stand up guy
# 1960    that s one small step for a man a giant leap f...
# 135                       soebat en bangoog kyk help niks
# 1062                                        saartjie soen
# 1441                    haar haan moet altyd koning kraai
# 2533                            a watched pot never boils
# 1734    mens moet nie werk om te lewe nie â hy moet le...
# 577                        scuse me while i kiss this guy
# 1384                                     cloak and dagger
# 1967                                        loaf of bread
# 1115                 daai manne by die spele ry toe speek
# 1434                       heard it through the grapevine
# 2752                           whole kit and caboodle the
# 1220                                            high time
# 2166          a bird in the hand is worth two in the bush
# 2505    ek probeer my skandelike verlede troos met goe...
# 2206                           a knight in shining armour
# 931                              without let or hindrance
# 1589                                       down the tubes
# 1933                                      take the mickey
# 1942    beter ã ã n vogel in de hand dan tien in de lucht
# 1581                                          round robin
# 889                                        back to basics
# 1901                                        berg toe gaan
# 888                                              loved up
# 2825            wat is die belangrikste â geluk of sukses
#                               ...
# 844     daardie ou mannetjie is darem maar â n kapoeva...
# 399                                      stick in the mud
# 1805                                        bang on about
# 2061                                    whistle and flute
# 2296              we few we happy few we band of brothers
# 2332                              zo gewonnen zo geronnen
# 2501                                       moaning minnie
# 1249                     barge pole wouldn t touch with a
# 612         a chain is only as strong as its weakest link
# 1533                                       name and shame
# 2528                                brummagem screwdriver
# 1348          je moet geen oude koeien uit de sloot halen
# 2600                                      hedge your bets
# 915                                          spelling bee
# 2215                              shanks mare shanks pony
# 198                                              skid row
# 331     as jyself dink en doen is jy beperk tot jousel...
# 1130                                         jimmy horner
# 249                              twelve good men and true
# 1538    as klein mensies groot skaduwees begin gooi is...
# 2467                                             bone dry
# 18                                    a drop in the ocean
# 1613    jors het al vroegmã re gedrink kanteldronk ger...
# 2008                                           getik wees
# 1947     though this be madness yet there is method in it
# 1521    some men are born mediocre some men achieve me...
# 302     â n mens kan met â n bokwa en â n lang span os...
# 2487                                 go like the clappers
# 30                                 neither here nor there
# 488                               all singing all dancing
# Name: text, Length: 2761, dtype: object
